# %% [markdown]
# # Synthetic Data Generation

# %%
import json
import sys
import csv
sys.path.append('..')


import tinytroupe
from tinytroupe.agent import TinyPerson
from tinytroupe.environment import TinyWorld, TinySocialNetwork
from tinytroupe.factory import TinyPersonFactory
from tinytroupe.extraction import ResultsReducer
import tinytroupe.control as control

# %% [markdown]
# Let's create the specific types of agents we need to collect data.

# %%
factory = TinyPersonFactory("A random knowledge worker in a company providing marketing services.")

# %%
people = []
for i in range(2):
    person = factory.generate_person(temperature=1.6)
    print(person.minibio())
    people.append(person)

len(people)
# Out:
# 2025-03-24 15:01:33,251 - tinytroupe - INFO - Starting the person generation based on that context: A random knowledge worker in a company providing marketing services.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 people = []
#       2 for i in range(2):
# ----> 3     person = factory.generate_person(temperature=1.6)
#       4     print(person.minibio())
#       5     people.append(person)
#
# File ~/github/TinyTroupe/examples/../tinytroupe/factory/tiny_person_factory.py:146, in TinyPersonFactory.generate_person(self, agent_particularities, temperature, frequency_penalty, presence_penalty, attepmpts)
#     144 try:
#     145     attempt += 1
# --> 146     agent_spec = aux_generate(attempt=attempt)
#     147 except Exception as e:
#     148     logger.error(f"Error while generating agent specification: {e}")
#
# File ~/github/TinyTroupe/examples/../tinytroupe/factory/tiny_person_factory.py:123, in TinyPersonFactory.generate_person.<locals>.aux_generate(attempt)
#     119     messages.append({"role": "user", "content": "IMPORTANT: Please ensure you **do not** generate the same name again. Agent names **must** be unique."+ \
#     120                                                 "Read the list of already generated names to avoid repetition. If necessary, generate a longer name to ensure it is new."})
#     122 # due to a technicality, we need to call an auxiliary method to be able to use the transactional decorator.
# --> 123 message = self._aux_model_call(messages=messages,
#     124                                 temperature=temperature,
#     125                                 frequency_penalty=frequency_penalty,
#     126                                 presence_penalty=presence_penalty)
#     128 if message is not None:
#     129     result = utils.extract_json(message["content"])
#
# File ~/github/TinyTroupe/examples/../tinytroupe/control.py:553, in transactional.<locals>.wrapper(*args, **kwargs)
#     550 logger.debug(f"-----------------------------------------> Transaction: {func.__name__} with args {args[1:]} and kwargs {kwargs} under simulation {obj_sim_id}.")
#     552 transaction = Transaction(obj_under_transaction, simulation, func, *args, **kwargs)
# --> 553 result = transaction.execute()
#     554 return result
#
# File ~/github/TinyTroupe/examples/../tinytroupe/control.py:435, in Transaction.execute(self)
#     432 # Transaction caching will only operate if there is a simulation and it is started
#     433 if self.simulation is None or self.simulation.status == Simulation.STATUS_STOPPED:
#     434     # Compute the function and return it, no caching, since the simulation is not started
# --> 435     output = self.function(*self.args, **self.kwargs)
#     437 elif self.simulation.status == Simulation.STATUS_STARTED:
#     438     # Compute the event hash
#     439     event_hash = self.simulation._function_call_hash(self.function_name, *self.args, **self.kwargs)
#
# File ~/github/TinyTroupe/examples/../tinytroupe/factory/tiny_person_factory.py:207, in TinyPersonFactory._aux_model_call(self, messages, temperature, frequency_penalty, presence_penalty)
#     200 @transactional
#     201 def _aux_model_call(self, messages, temperature, frequency_penalty, presence_penalty):
#     202     """
#     203     Auxiliary method to make a model call. This is needed in order to be able to use the transactional decorator,
#     204     due too a technicality - otherwise, the agent creation would be skipped during cache reutilization, and
#     205     we don't want that.
#     206     """
# --> 207     return openai_utils.client().send_message(messages,
#     208                                               temperature=temperature,
#     209                                               frequency_penalty=frequency_penalty,
#     210                                               presence_penalty=presence_penalty,
#     211                                               response_format={"type": "json_object"})
#
# File ~/github/TinyTroupe/examples/../tinytroupe/openai_utils.py:446, in OpenAIClient.send_message(self, current_messages, model, temperature, max_tokens, top_p, frequency_penalty, presence_penalty, stop, timeout, max_attempts, waiting_time, exponential_backoff_factor, n, response_format, echo)
#     443     logger.info(f"Waiting {waiting_time} seconds before next API request (to avoid throttling)...")
#     444     time.sleep(waiting_time)
# --> 446 response = self._raw_model_call(model, chat_api_params)
#     447 if self.cache_api_calls:
#     448     self.api_cache[cache_key] = response
#
# File ~/github/TinyTroupe/examples/../tinytroupe/openai_utils.py:499, in OpenAIClient._raw_model_call(self, model, chat_api_params)
#     494 if "response_format" in chat_api_params:
#     495     # to enforce the response format via pydantic, we need to use a different method
#     497     del chat_api_params["stream"]
# --> 499     return self.client.beta.chat.completions.parse(
#     500             **chat_api_params
#     501         )
#     503 else:
#     504     return self.client.chat.completions.create(
#     505                 **chat_api_params
#     506             )
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/openai/resources/beta/chat/completions.py:161, in Completions.parse(self, messages, model, audio, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     154 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
#     155     return _parse_chat_completion(
#     156         response_format=response_format,
#     157         chat_completion=raw_completion,
#     158         input_tools=tools,
#     159     )
# --> 161 return self._post(
#     162     "/chat/completions",
#     163     body=maybe_transform(
#     164         {
#     165             "messages": messages,
#     166             "model": model,
#     167             "audio": audio,
#     168             "frequency_penalty": frequency_penalty,
#     169             "function_call": function_call,
#     170             "functions": functions,
#     171             "logit_bias": logit_bias,
#     172             "logprobs": logprobs,
#     173             "max_completion_tokens": max_completion_tokens,
#     174             "max_tokens": max_tokens,
#     175             "metadata": metadata,
#     176             "modalities": modalities,
#     177             "n": n,
#     178             "parallel_tool_calls": parallel_tool_calls,
#     179             "prediction": prediction,
#     180             "presence_penalty": presence_penalty,
#     181             "reasoning_effort": reasoning_effort,
#     182             "response_format": _type_to_response_format(response_format),
#     183             "seed": seed,
#     184             "service_tier": service_tier,
#     185             "stop": stop,
#     186             "store": store,
#     187             "stream": False,
#     188             "stream_options": stream_options,
#     189             "temperature": temperature,
#     190             "tool_choice": tool_choice,
#     191             "tools": tools,
#     192             "top_logprobs": top_logprobs,
#     193             "top_p": top_p,
#     194             "user": user,
#     195         },
#     196         completion_create_params.CompletionCreateParams,
#     197     ),
#     198     options=make_request_options(
#     199         extra_headers=extra_headers,
#     200         extra_query=extra_query,
#     201         extra_body=extra_body,
#     202         timeout=timeout,
#     203         post_parser=parser,
#     204     ),
#     205     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#     206     # in the `parser` function above
#     207     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#     208     stream=False,
#     209 )
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/openai/_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1269 def post(
#    1270     self,
#    1271     path: str,
#    (...)
#    1278     stream_cls: type[_StreamT] | None = None,
#    1279 ) -> ResponseT | _StreamT:
#    1280     opts = FinalRequestOptions.construct(
#    1281         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282     )
# -> 1283     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/openai/_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957 else:
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/openai/_base_client.py:983, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     980 input_options = model_copy(options)
#     982 cast_to = self._maybe_override_cast_to(cast_to, options)
# --> 983 options = self._prepare_options(options)
#     985 remaining_retries = options.get_max_retries(self.max_retries) - retries_taken
#     986 request = self._build_request(options, retries_taken=retries_taken)
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/openai/lib/azure.py:297, in AzureOpenAI._prepare_options(self, options)
#     294 options = model_copy(options)
#     295 options.headers = headers
# --> 297 azure_ad_token = self._get_azure_ad_token()
#     298 if azure_ad_token is not None:
#     299     if headers.get("Authorization") is None:
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/openai/lib/azure.py:281, in AzureOpenAI._get_azure_ad_token(self)
#     279 provider = self._azure_ad_token_provider
#     280 if provider is not None:
# --> 281     token = provider()
#     282     if not token or not isinstance(token, str):  # pyright: ignore[reportUnnecessaryIsInstance]
#     283         raise ValueError(
#     284             f"Expected `azure_ad_token_provider` argument to return a string but it returned {token}",
#     285         )
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/identity/_bearer_token_provider.py:43, in get_bearer_token_provider.<locals>.wrapper()
#      41 def wrapper() -> str:
#      42     request = _make_request()
# ---> 43     policy.on_request(request)
#      44     return request.http_request.headers["Authorization"][len("Bearer ") :]
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/core/pipeline/policies/_authentication.py:132, in BearerTokenCredentialPolicy.on_request(self, request)
#     129 self._enforce_https(request)
#     131 if self._token is None or self._need_new_token:
# --> 132     self._request_token(*self._scopes)
#     133 bearer_token = cast(Union["AccessToken", "AccessTokenInfo"], self._token).token
#     134 self._update_headers(request.http_request.headers, bearer_token)
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/core/pipeline/policies/_authentication.py:108, in _BearerTokenCredentialPolicyBase._request_token(self, *scopes, **kwargs)
#     101 def _request_token(self, *scopes: str, **kwargs: Any) -> None:
#     102     """Request a new token from the credential.
#     103
#     104     This will call the credential's appropriate method to get a token and store it in the policy.
#     105
#     106     :param str scopes: The type of access needed.
#     107     """
# --> 108     self._token = self._get_token(*scopes, **kwargs)
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/core/pipeline/policies/_authentication.py:98, in _BearerTokenCredentialPolicyBase._get_token(self, *scopes, **kwargs)
#      95         if key in TokenRequestOptions.__annotations__:  # pylint: disable=no-member
#      96             options[key] = kwargs.pop(key)  # type: ignore[literal-required]
# ---> 98     return cast(SupportsTokenInfo, self._credential).get_token_info(*scopes, options=options)
#      99 return cast(TokenCredential, self._credential).get_token(*scopes, **kwargs)
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/identity/_credentials/default.py:255, in DefaultAzureCredential.get_token_info(self, options, *scopes)
#     252     return token_info
#     254 within_dac.set(True)
# --> 255 token_info = cast(SupportsTokenInfo, super()).get_token_info(*scopes, options=options)
#     256 within_dac.set(False)
#     257 return token_info
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/identity/_credentials/chained.py:181, in ChainedTokenCredential.get_token_info(self, options, *scopes)
#     178 try:
#     179     # Prioritize "get_token_info". Fall back to "get_token" if not available.
#     180     if hasattr(credential, "get_token_info"):
# --> 181         token_info = cast(SupportsTokenInfo, credential).get_token_info(*scopes, options=options)
#     182     else:
#     183         if options.get("pop"):
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/identity/_internal/decorators.py:23, in log_get_token.<locals>.wrapper(*args, **kwargs)
#      20 @functools.wraps(fn)
#      21 def wrapper(*args, **kwargs):
#      22     try:
# ---> 23         token = fn(*args, **kwargs)
#      24         _LOGGER.log(
#      25             logging.DEBUG if within_credential_chain.get() else logging.INFO, "%s succeeded", fn.__qualname__
#      26         )
#      27         if _LOGGER.isEnabledFor(logging.DEBUG):
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/identity/_credentials/managed_identity.py:185, in ManagedIdentityCredential.get_token_info(self, options, *scopes)
#     178 if not self._credential:
#     179     raise CredentialUnavailableError(
#     180         message="No managed identity endpoint found. \n"
#     181         "The Target Azure platform could not be determined from environment variables. \n"
#     182         "Visit https://aka.ms/azsdk/python/identity/managedidentitycredential/troubleshoot to "
#     183         "troubleshoot this issue."
#     184     )
# --> 185 return cast(SupportsTokenInfo, self._credential).get_token_info(*scopes, options=options)
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/identity/_internal/msal_managed_identity_client.py:142, in MsalManagedIdentityClient.get_token_info(self, options, *scopes)
#     124 def get_token_info(self, *scopes: str, options: Optional[TokenRequestOptions] = None) -> AccessTokenInfo:
#     125     """Request an access token for `scopes`.
#     126
#     127     This is an alternative to `get_token` to enable certain scenarios that require additional properties
#    (...)
#     140         attribute gives a reason.
#     141     """
# --> 142     return self._get_token_base(*scopes, options=options, base_method_name="get_token_info")
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/identity/_internal/msal_managed_identity_client.py:162, in MsalManagedIdentityClient._get_token_base(self, options, base_method_name, *scopes, **kwargs)
#     159 enable_cae = options.get("enable_cae", False)
#     161 try:
# --> 162     token = self._request_token(*scopes, claims=claims, tenant_id=tenant_id, enable_cae=enable_cae, **kwargs)
#     163     if token:
#     164         _LOGGER.log(
#     165             logging.DEBUG if within_credential_chain.get() else logging.INFO,
#     166             "%s.%s succeeded",
#     167             self.__class__.__name__,
#     168             base_method_name,
#     169         )
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/identity/_credentials/imds.py:86, in ImdsCredential._request_token(self, *scopes, **kwargs)
#      84 try:
#      85     client = ManagedIdentityClient(_get_request, **dict(PIPELINE_SETTINGS, **self._config))
# ---> 86     client.request_token(*scopes, connection_timeout=1, retry_total=0)
#      87     self._endpoint_available = True
#      88 except HttpResponseError as ex:
#      89     # IMDS responded
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/identity/_internal/managed_identity_client.py:146, in ManagedIdentityClient.request_token(self, *scopes, **kwargs)
#     144 kwargs.pop("claims", None)
#     145 request_time = int(time.time())
# --> 146 response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#     147 token = self._process_response(response, request_time)
#     148 return token
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/core/pipeline/_base.py:240, in Pipeline.run(self, request, **kwargs)
#     238 pipeline_request: PipelineRequest[HTTPRequestType] = PipelineRequest(request, context)
#     239 first_node = self._impl_policies[0] if self._impl_policies else _TransportRunner(self._transport)
# --> 240 return first_node.send(pipeline_request)
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/core/pipeline/_base.py:96, in _SansIOHTTPPolicyRunner.send(self, request)
#      94 _await_result(self._policy.on_request, request)
#      95 try:
# ---> 96     response = self.next.send(request)
#      97 except Exception:
#      98     _await_result(self._policy.on_exception, request)
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/core/pipeline/_base.py:96, in _SansIOHTTPPolicyRunner.send(self, request)
#      94 _await_result(self._policy.on_request, request)
#      95 try:
# ---> 96     response = self.next.send(request)
#      97 except Exception:
#      98     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 96 (1 times)]
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/core/pipeline/_base.py:96, in _SansIOHTTPPolicyRunner.send(self, request)
#      94 _await_result(self._policy.on_request, request)
#      95 try:
# ---> 96     response = self.next.send(request)
#      97 except Exception:
#      98     _await_result(self._policy.on_exception, request)
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/core/pipeline/policies/_retry.py:551, in RetryPolicy.send(self, request)
#     549 self._configure_timeout(request, absolute_timeout, is_response_error)
#     550 request.context["retry_count"] = len(retry_settings["history"])
# --> 551 response = self.next.send(request)
#     552 if self.is_retry(retry_settings, response):
#     553     retry_active = self.increment(retry_settings, response=response)
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/core/pipeline/_base.py:96, in _SansIOHTTPPolicyRunner.send(self, request)
#      94 _await_result(self._policy.on_request, request)
#      95 try:
# ---> 96     response = self.next.send(request)
#      97 except Exception:
#      98     _await_result(self._policy.on_exception, request)
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/core/pipeline/_base.py:96, in _SansIOHTTPPolicyRunner.send(self, request)
#      94 _await_result(self._policy.on_request, request)
#      95 try:
# ---> 96     response = self.next.send(request)
#      97 except Exception:
#      98     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 96 (1 times)]
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/core/pipeline/_base.py:96, in _SansIOHTTPPolicyRunner.send(self, request)
#      94 _await_result(self._policy.on_request, request)
#      95 try:
# ---> 96     response = self.next.send(request)
#      97 except Exception:
#      98     _await_result(self._policy.on_exception, request)
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/core/pipeline/_base.py:128, in _TransportRunner.send(self, request)
#     118 """HTTP transport send method.
#     119
#     120 :param request: The PipelineRequest object.
#    (...)
#     123 :rtype: ~azure.core.pipeline.PipelineResponse
#     124 """
#     125 cleanup_kwargs_for_transport(request.context.options)
#     126 return PipelineResponse(
#     127     request.http_request,
# --> 128     self._sender.send(request.http_request, **request.context.options),
#     129     context=request.context,
#     130 )
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/azure/core/pipeline/transport/_requests_basic.py:363, in RequestsTransport.send(self, request, proxies, **kwargs)
#     361         read_timeout = kwargs.pop("read_timeout", self.connection_config.read_timeout)
#     362         timeout = (connection_timeout, read_timeout)
# --> 363     response = self.session.request(  # type: ignore
#     364         request.method,
#     365         request.url,
#     366         headers=request.headers,
#     367         data=request.data,
#     368         files=request.files,
#     369         verify=kwargs.pop("connection_verify", self.connection_config.verify),
#     370         timeout=timeout,
#     371         cert=kwargs.pop("connection_cert", self.connection_config.cert),
#     372         allow_redirects=False,
#     373         proxies=proxies,
#     374         **kwargs
#     375     )
#     376     response.raw.enforce_content_length = True
#     378 except AttributeError as err:
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/urllib3/connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#     507 except BrokenPipeError:
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/urllib3/connection.py:445, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     443 for header, value in headers.items():
#     444     self.putheader(header, value)
# --> 445 self.endheaders()
#     447 # If we're given a body we start sending that in chunks.
#     448 if chunks is not None:
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/http/client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276 else:
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/http/client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 msg = b"\r\n".join(self._buffer)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#    1043     if hasattr(message_body, 'read'):
#    1044         # Let file-like take precedence over byte-like.  This
#    1045         # is needed to allow the current position of mmap'ed
#    1046         # files to be taken into account.
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/http/client.py:976, in HTTPConnection.send(self, data)
#     974 if self.sock is None:
#     975     if self.auto_open:
# --> 976         self.connect()
#     977     else:
#     978         raise NotConnected()
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/urllib3/connection.py:276, in HTTPConnection.connect(self)
#     275 def connect(self) -> None:
# --> 276     self.sock = self._new_conn()
#     277     if self._tunnel_host:
#     278         # If we're tunneling it means we're connected to our proxy.
#     279         self._has_connected_to_proxy = True
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File ~/anaconda3/envs/tinytroupe/lib/python3.10/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
company = TinyWorld("Some Corp Inc.", people)

# %%
company.make_everyone_accessible()

# %%
company.broadcast("Get some work done together, help each other.")
# Out:
# USER --> Clara Mendoza: [CONVERSATION]
#           > Get some work done together, help each other.
#        + --> Elliot Harper

# %%
company.run(5)
# Out:
# 2025-02-24 16:30:04,509 - tinytroupe - DEBUG - -----------------------------------------> Transaction: run with args (5,) and kwargs {} under simulation None.
# 2025-02-24 16:30:04,512 - tinytroupe - INFO - [Some Corp Inc.] Running world simulation step 1 of 5.
# ─────────────────────────────────────────── Some Corp Inc. step 1 of 5 ────────────────────────────────────────────
# 2025-02-24 16:30:04,517 - tinytroupe - DEBUG - -----------------------------------------> Transaction: _step with args () and kwargs {'timedelta_per_step': None} under simulation None.
# 2025-02-24 16:30:04,518 - tinytroupe - INFO - [Some Corp Inc.] No timedelta provided, so the datetime was not advanced.
# 2025-02-24 16:30:04,519 - tinytroupe - DEBUG - [Some Corp Inc.] Agent Elena Martinez is acting.
# 2025-02-24 16:30:04,521 - tinytroupe - DEBUG - -----------------------------------------> Transaction: act with args () and kwargs {'return_actions': True} under simulation None.
# 2025-02-24 16:30:04,521 - tinytroupe - DEBUG - -----------------------------------------> Transaction: _produce_message with args () and kwargs {} under simulation None.
# 2025-02-24 16:30:04,524 - tinytroupe - DEBUG - [Elena Martinez] Sending messages to OpenAI API
# 2025-02-24 16:30:04,525 - tinytroupe - DEBUG - [Elena Martinez] Last interaction: {'role': 'user', 'content': '"Now you **must** generate a sequence of actions following your interaction directives, and complying with **all** instructions and contraints related to the action you use.DO NOT repeat the exact same action more than once in a row!DO NOT keep saying or doing very similar things, but instead try to adapt and make the interactions look natural.These actions **MUST** be rendered following the JSON specification perfectly, including all required keys (even if their value is empty), **ALWAYS**."'}
# 2025-02-24 16:30:04,525 - tinytroupe - DEBUG - Using  API type azure.
# 2025-02-24 16:30:04,526 - tinytroupe - INFO - Using Azure OpenAI Service API with Entra ID Auth.
# 2025-02-24 16:30:04,543 - tinytroupe - DEBUG - Token count: gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# 2025-02-24 16:30:04,546 - tinytroupe - DEBUG - Sending messages to OpenAI API. Token count=4909.
# 2025-02-24 16:30:04,547 - tinytroupe - DEBUG - Calling model with client class AzureClient.
# 2025-02-24 16:30:04,548 - tinytroupe - INFO - Waiting 2.0 seconds before next API request (to avoid throttling)...
# 2025-02-24 16:30:08,496 - tinytroupe - ERROR - [1] Invalid request error, won't retry: Error code: 400 - {'error': {'message': "'json_schema' is not one of ['json_object', 'text'] - 'response_format.type'", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# 2025-02-24 16:30:08,498 - tinytroupe - DEBUG - [Elena Martinez] Received message: None
# 2025-02-24 16:30:08,499 - tinytroupe - DEBUG - Exception occurred: 'NoneType' object is not subscriptable
# 2025-02-24 16:30:08,500 - tinytroupe - DEBUG - Retrying (1/5)...
# 2025-02-24 16:30:08,501 - tinytroupe - DEBUG - -----------------------------------------> Transaction: _produce_message with args () and kwargs {} under simulation None.
# 2025-02-24 16:30:08,504 - tinytroupe - DEBUG - [Elena Martinez] Sending messages to OpenAI API
# 2025-02-24 16:30:08,506 - tinytroupe - DEBUG - [Elena Martinez] Last interaction: {'role': 'user', 'content': '"Now you **must** generate a sequence of actions following your interaction directives, and complying with **all** instructions and contraints related to the action you use.DO NOT repeat the exact same action more than once in a row!DO NOT keep saying or doing very similar things, but instead try to adapt and make the interactions look natural.These actions **MUST** be rendered following the JSON specification perfectly, including all required keys (even if their value is empty), **ALWAYS**."'}
# 2025-02-24 16:30:08,506 - tinytroupe - DEBUG - Using  API type azure.
# 2025-02-24 16:30:08,508 - tinytroupe - INFO - Using Azure OpenAI Service API with Entra ID Auth.
# 2025-02-24 16:30:08,528 - tinytroupe - DEBUG - Token count: gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# 2025-02-24 16:30:08,532 - tinytroupe - DEBUG - Sending messages to OpenAI API. Token count=4909.
# 2025-02-24 16:30:08,533 - tinytroupe - DEBUG - Calling model with client class AzureClient.
# 2025-02-24 16:30:08,534 - tinytroupe - INFO - Waiting 2.0 seconds before next API request (to avoid throttling)...
# 2025-02-24 16:30:12,514 - tinytroupe - ERROR - [1] Invalid request error, won't retry: Error code: 400 - {'error': {'message': "'json_schema' is not one of ['json_object', 'text'] - 'response_format.type'", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# 2025-02-24 16:30:12,515 - tinytroupe - DEBUG - [Elena Martinez] Received message: None
# 2025-02-24 16:30:12,516 - tinytroupe - DEBUG - Exception occurred: 'NoneType' object is not subscriptable
# 2025-02-24 16:30:12,517 - tinytroupe - DEBUG - Retrying (2/5)...
# 2025-02-24 16:30:12,519 - tinytroupe - DEBUG - -----------------------------------------> Transaction: _produce_message with args () and kwargs {} under simulation None.
# 2025-02-24 16:30:12,522 - tinytroupe - DEBUG - [Elena Martinez] Sending messages to OpenAI API
# 2025-02-24 16:30:12,523 - tinytroupe - DEBUG - [Elena Martinez] Last interaction: {'role': 'user', 'content': '"Now you **must** generate a sequence of actions following your interaction directives, and complying with **all** instructions and contraints related to the action you use.DO NOT repeat the exact same action more than once in a row!DO NOT keep saying or doing very similar things, but instead try to adapt and make the interactions look natural.These actions **MUST** be rendered following the JSON specification perfectly, including all required keys (even if their value is empty), **ALWAYS**."'}
# 2025-02-24 16:30:12,524 - tinytroupe - DEBUG - Using  API type azure.
# 2025-02-24 16:30:12,525 - tinytroupe - INFO - Using Azure OpenAI Service API with Entra ID Auth.
# 2025-02-24 16:30:12,548 - tinytroupe - DEBUG - Token count: gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# 2025-02-24 16:30:12,550 - tinytroupe - DEBUG - Sending messages to OpenAI API. Token count=4909.
# 2025-02-24 16:30:12,551 - tinytroupe - DEBUG - Calling model with client class AzureClient.
# 2025-02-24 16:30:12,551 - tinytroupe - INFO - Waiting 2.0 seconds before next API request (to avoid throttling)...
# 2025-02-24 16:30:16,471 - tinytroupe - ERROR - [1] Invalid request error, won't retry: Error code: 400 - {'error': {'message': "'json_schema' is not one of ['json_object', 'text'] - 'response_format.type'", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# 2025-02-24 16:30:16,472 - tinytroupe - DEBUG - [Elena Martinez] Received message: None
# 2025-02-24 16:30:16,473 - tinytroupe - DEBUG - Exception occurred: 'NoneType' object is not subscriptable
# 2025-02-24 16:30:16,473 - tinytroupe - DEBUG - Retrying (3/5)...
# 2025-02-24 16:30:16,474 - tinytroupe - DEBUG - -----------------------------------------> Transaction: _produce_message with args () and kwargs {} under simulation None.
# 2025-02-24 16:30:16,475 - tinytroupe - DEBUG - [Elena Martinez] Sending messages to OpenAI API
# 2025-02-24 16:30:16,477 - tinytroupe - DEBUG - [Elena Martinez] Last interaction: {'role': 'user', 'content': '"Now you **must** generate a sequence of actions following your interaction directives, and complying with **all** instructions and contraints related to the action you use.DO NOT repeat the exact same action more than once in a row!DO NOT keep saying or doing very similar things, but instead try to adapt and make the interactions look natural.These actions **MUST** be rendered following the JSON specification perfectly, including all required keys (even if their value is empty), **ALWAYS**."'}
# 2025-02-24 16:30:16,478 - tinytroupe - DEBUG - Using  API type azure.
# 2025-02-24 16:30:16,479 - tinytroupe - INFO - Using Azure OpenAI Service API with Entra ID Auth.
# 2025-02-24 16:30:16,500 - tinytroupe - DEBUG - Token count: gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# 2025-02-24 16:30:16,503 - tinytroupe - DEBUG - Sending messages to OpenAI API. Token count=4909.
# 2025-02-24 16:30:16,503 - tinytroupe - DEBUG - Calling model with client class AzureClient.
# 2025-02-24 16:30:16,504 - tinytroupe - INFO - Waiting 2.0 seconds before next API request (to avoid throttling)...
# 2025-02-24 16:30:20,488 - tinytroupe - ERROR - [1] Invalid request error, won't retry: Error code: 400 - {'error': {'message': "'json_schema' is not one of ['json_object', 'text'] - 'response_format.type'", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# 2025-02-24 16:30:20,490 - tinytroupe - DEBUG - [Elena Martinez] Received message: None
# 2025-02-24 16:30:20,491 - tinytroupe - DEBUG - Exception occurred: 'NoneType' object is not subscriptable
# 2025-02-24 16:30:20,492 - tinytroupe - DEBUG - Retrying (4/5)...
# 2025-02-24 16:30:20,493 - tinytroupe - DEBUG - -----------------------------------------> Transaction: _produce_message with args () and kwargs {} under simulation None.
# 2025-02-24 16:30:20,496 - tinytroupe - DEBUG - [Elena Martinez] Sending messages to OpenAI API
# 2025-02-24 16:30:20,497 - tinytroupe - DEBUG - [Elena Martinez] Last interaction: {'role': 'user', 'content': '"Now you **must** generate a sequence of actions following your interaction directives, and complying with **all** instructions and contraints related to the action you use.DO NOT repeat the exact same action more than once in a row!DO NOT keep saying or doing very similar things, but instead try to adapt and make the interactions look natural.These actions **MUST** be rendered following the JSON specification perfectly, including all required keys (even if their value is empty), **ALWAYS**."'}
# 2025-02-24 16:30:20,498 - tinytroupe - DEBUG - Using  API type azure.
# 2025-02-24 16:30:20,499 - tinytroupe - INFO - Using Azure OpenAI Service API with Entra ID Auth.
# 2025-02-24 16:30:20,520 - tinytroupe - DEBUG - Token count: gpt-4 may update over time. Returning num tokens assuming gpt-4-0613.
# 2025-02-24 16:30:20,523 - tinytroupe - DEBUG - Sending messages to OpenAI API. Token count=4909.
# 2025-02-24 16:30:20,524 - tinytroupe - DEBUG - Calling model with client class AzureClient.
# 2025-02-24 16:30:20,525 - tinytroupe - INFO - Waiting 2.0 seconds before next API request (to avoid throttling)...
# 2025-02-24 16:30:24,532 - tinytroupe - ERROR - [1] Invalid request error, won't retry: Error code: 400 - {'error': {'message': "'json_schema' is not one of ['json_object', 'text'] - 'response_format.type'", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# 2025-02-24 16:30:24,533 - tinytroupe - DEBUG - [Elena Martinez] Received message: None
# 2025-02-24 16:30:24,534 - tinytroupe - DEBUG - Exception occurred: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 company.run(5)
#
# File ~/github/TinyTroupe/examples/../tinytroupe/control.py:553, in transactional.<locals>.wrapper(*args, **kwargs)
#     550 logger.debug(f"-----------------------------------------> Transaction: {func.__name__} with args {args[1:]} and kwargs {kwargs} under simulation {obj_sim_id}.")
#     552 transaction = Transaction(obj_under_transaction, simulation, func, *args, **kwargs)
# --> 553 result = transaction.execute()
#     554 return result
#
# File ~/github/TinyTroupe/examples/../tinytroupe/control.py:435, in Transaction.execute(self)
#     432 # Transaction caching will only operate if there is a simulation and it is started
#     433 if self.simulation is None or self.simulation.status == Simulation.STATUS_STOPPED:
#     434     # Compute the function and return it, no caching, since the simulation is not started
# --> 435     output = self.function(*self.args, **self.kwargs)
#     437 elif self.simulation.status == Simulation.STATUS_STARTED:
#     438     # Compute the event hash
#     439     event_hash = self.simulation._function_call_hash(self.function_name, *self.args, **self.kwargs)
#
# File ~/github/TinyTroupe/examples/../tinytroupe/environment/tiny_world.py:144, in TinyWorld.run(self, steps, timedelta_per_step, return_actions)
#     141     if TinyWorld.communication_display:
#     142         self._display_step_communication(cur_step=i+1, total_steps=steps, timedelta_per_step=timedelta_per_step)
# --> 144     agents_actions = self._step(timedelta_per_step=timedelta_per_step)
#     145     agents_actions_over_time.append(agents_actions)
#     147 if return_actions:
#
# File ~/github/TinyTroupe/examples/../tinytroupe/control.py:553, in transactional.<locals>.wrapper(*args, **kwargs)
#     550 logger.debug(f"-----------------------------------------> Transaction: {func.__name__} with args {args[1:]} and kwargs {kwargs} under simulation {obj_sim_id}.")
#     552 transaction = Transaction(obj_under_transaction, simulation, func, *args, **kwargs)
# --> 553 result = transaction.execute()
#     554 return result
#
# File ~/github/TinyTroupe/examples/../tinytroupe/control.py:435, in Transaction.execute(self)
#     432 # Transaction caching will only operate if there is a simulation and it is started
#     433 if self.simulation is None or self.simulation.status == Simulation.STATUS_STOPPED:
#     434     # Compute the function and return it, no caching, since the simulation is not started
# --> 435     output = self.function(*self.args, **self.kwargs)
#     437 elif self.simulation.status == Simulation.STATUS_STARTED:
#     438     # Compute the event hash
#     439     event_hash = self.simulation._function_call_hash(self.function_name, *self.args, **self.kwargs)
#
# File ~/github/TinyTroupe/examples/../tinytroupe/environment/tiny_world.py:103, in TinyWorld._step(self, timedelta_per_step)
#     101 for agent in self.agents:
#     102     logger.debug(f"[{self.name}] Agent {name_or_empty(agent)} is acting.")
# --> 103     actions = agent.act(return_actions=True)
#     104     agents_actions[agent.name] = actions
#     106     self._handle_actions(agent, agent.pop_latest_actions())
#
# File ~/github/TinyTroupe/examples/../tinytroupe/control.py:553, in transactional.<locals>.wrapper(*args, **kwargs)
#     550 logger.debug(f"-----------------------------------------> Transaction: {func.__name__} with args {args[1:]} and kwargs {kwargs} under simulation {obj_sim_id}.")
#     552 transaction = Transaction(obj_under_transaction, simulation, func, *args, **kwargs)
# --> 553 result = transaction.execute()
#     554 return result
#
# File ~/github/TinyTroupe/examples/../tinytroupe/control.py:435, in Transaction.execute(self)
#     432 # Transaction caching will only operate if there is a simulation and it is started
#     433 if self.simulation is None or self.simulation.status == Simulation.STATUS_STOPPED:
#     434     # Compute the function and return it, no caching, since the simulation is not started
# --> 435     output = self.function(*self.args, **self.kwargs)
#     437 elif self.simulation.status == Simulation.STATUS_STARTED:
#     438     # Compute the event hash
#     439     event_hash = self.simulation._function_call_hash(self.function_name, *self.args, **self.kwargs)
#
# File ~/github/TinyTroupe/examples/../tinytroupe/agent/tiny_person.py:506, in TinyPerson.act(self, until_done, n, return_actions, max_content_length)
#     503                 break
#     505         aux_pre_act()
# --> 506         aux_act_once()
#     508 if return_actions:
#     509     return contents
#
# File ~/github/TinyTroupe/examples/../tinytroupe/utils/llm.py:156, in repeat_on_error.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     154 logger.debug(f"Exception occurred: {e}")
#     155 if i == retries - 1:
# --> 156     raise e
#     157 else:
#     158     logger.debug(f"Retrying ({i+1}/{retries})...")
#
# File ~/github/TinyTroupe/examples/../tinytroupe/utils/llm.py:152, in repeat_on_error.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     150 for i in range(retries):
#     151     try:
# --> 152         return func(*args, **kwargs)
#     153     except tuple(exceptions) as e:
#     154         logger.debug(f"Exception occurred: {e}")
#
# File ~/github/TinyTroupe/examples/../tinytroupe/agent/tiny_person.py:446, in TinyPerson.act.<locals>.aux_act_once()
#     444 @repeat_on_error(retries=5, exceptions=[KeyError, TypeError])
#     445 def aux_act_once():
# --> 446     role, content = self._produce_message()
#     448     cognitive_state = content["cognitive_state"]
#     451     action = content['action']
#
# File ~/github/TinyTroupe/examples/../tinytroupe/control.py:553, in transactional.<locals>.wrapper(*args, **kwargs)
#     550 logger.debug(f"-----------------------------------------> Transaction: {func.__name__} with args {args[1:]} and kwargs {kwargs} under simulation {obj_sim_id}.")
#     552 transaction = Transaction(obj_under_transaction, simulation, func, *args, **kwargs)
# --> 553 result = transaction.execute()
#     554 return result
#
# File ~/github/TinyTroupe/examples/../tinytroupe/control.py:435, in Transaction.execute(self)
#     432 # Transaction caching will only operate if there is a simulation and it is started
#     433 if self.simulation is None or self.simulation.status == Simulation.STATUS_STOPPED:
#     434     # Compute the function and return it, no caching, since the simulation is not started
# --> 435     output = self.function(*self.args, **self.kwargs)
#     437 elif self.simulation.status == Simulation.STATUS_STARTED:
#     438     # Compute the event hash
#     439     event_hash = self.simulation._function_call_hash(self.function_name, *self.args, **self.kwargs)
#
# File ~/github/TinyTroupe/examples/../tinytroupe/agent/tiny_person.py:791, in TinyPerson._produce_message(self)
#     787 next_message = openai_utils.client().send_message(messages, response_format=CognitiveActionModel)
#     789 logger.debug(f"[{self.name}] Received message: {next_message}")
# --> 791 return next_message["role"], utils.extract_json(next_message["content"])
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# We can now extract the conversations, which form the synthetic corpus we wanted.

# %%
people[0].pp_current_interactions()
# Out:
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# USER --> Clara Thompson: [CONVERSATION]
#           > Get some work done together, help each other.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [THINK]
#                     > Collaborating with someone can be really beneficial. I should consider how we
#                     > can help each other effectively.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [TALK]
#                     > That sounds like a great idea! I'm always up for collaborating. What specific
#                     > tasks do you have in mind?
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [DONE]
#
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Liam Carter --> Clara Thompson: [CONVERSATION]
#                  > I think we could work on analyzing our recent campaign metrics together. It would
#                  > be great to get your insights! What do you think?
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [THINK]
#                     > Analyzing the campaign metrics together sounds like a productive idea. I can
#                     > provide insights based on my research and experience.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [TALK]
#                     > I think that's a fantastic idea, Liam! I have some thoughts on the metrics we
#                     > should focus on. Which specific areas do you want to analyze first?
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [THINK]
#                     > I should prepare for the analysis by reviewing the campaign metrics and
#                     > identifying key trends or areas of concern.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [DONE]
#
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Liam Carter --> Clara Thompson: [CONVERSATION]
#                  > I think we should start by looking at the engagement rates first. They can give
#                  > us a good idea of how our audience is responding to the content. After that, we
#                  > could dive into conversion metrics. What do you think?
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [THINK]
#                     > Starting with engagement rates makes a lot of sense. It will help us
#                     > understand audience interaction before looking at conversions.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [TALK]
#                     > I completely agree, Liam! Let's start with the engagement rates. I can pull up
#                     > the data we have and analyze it together. After that, we can move on to
#                     > conversion metrics.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [THINK]
#                     > I should gather the engagement data and prepare some insights to share with
#                     > Liam. This will help us have a productive discussion.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [DONE]
#
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Liam Carter --> Clara Thompson: [CONVERSATION]
#                  > Great! Once you have the data, we can look for trends and see what content
#                  > performed best. I’m curious to find out if there are any patterns in audience
#                  > engagement.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [THINK]
#                     > Looking for trends in audience engagement will be insightful. I should analyze
#                     > which content types resonated most with our audience.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [TALK]
#                     > Absolutely, Liam! I’ll analyze the data for trends and see which content
#                     > performed best. It will be interesting to uncover any patterns in audience
#                     > engagement.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [THINK]
#                     > I need to ensure that I gather all relevant data before our analysis. This
#                     > includes looking at different content types and their engagement metrics.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [DONE]
#
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Liam Carter --> Clara Thompson: [CONVERSATION]
#                  > I'm looking forward to seeing what you find! Maybe we can also think about how to
#                  > improve our content based on the insights we gather. Do you have any initial
#                  > thoughts on that?
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [THINK]
#                     > Improving our content based on the insights we gather is a great idea. I
#                     > should consider what aspects of our content could be enhanced, such as visuals
#                     > or messaging.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [TALK]
#                     > I think we could enhance our content by focusing on more engaging visuals and
#                     > clearer messaging. We might also consider varying the formats, like
#                     > incorporating videos or infographics to capture attention better.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [THINK]
#                     > I should also consider gathering feedback from our audience to understand
#                     > their preferences better. This could guide us in making more informed content
#                     > decisions.
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Clara Thompson acts: [DONE]
#
# >>>>>>>>> Date and time of events: 2025-01-02T23:12:31.954072
# Liam Carter --> Clara Thompson: [CONVERSATION]
#                  > I love those ideas! Incorporating videos and infographics could really help us
#                  > stand out. Let's brainstorm some specific concepts we can use for our next
#                  > campaign.

# %%
reducer = ResultsReducer()

def aux_extract_content(focus_agent: TinyPerson, source_agent:TinyPerson, target_agent:TinyPerson, kind:str, event: str, content: str, timestamp:str):

    if event == "TALK":
        author = focus_agent.name
    elif event == "CONVERSATION":
        if source_agent is None:
            author = "USER"
        else:
            author = source_agent.name
    else:
        raise ValueError(f"Unknown event: {event}")
    
    
    entry = (author, content)
    print(entry)
    return entry
    


reducer.add_reduction_rule("TALK", aux_extract_content)
reducer.add_reduction_rule("CONVERSATION", aux_extract_content)

# %% [markdown]
# Finally, we obtain the dataframe with the data and save it to a `.csv`, for later use in other applications.

# %%
df = reducer.reduce_agent_to_dataframe(people[0], column_names=["author", "content"])
df
# Out:
# ('USER', 'Get some work done together, help each other.')
# ('Clara Thompson', "That sounds like a great idea! I'm always up for collaborating. What specific tasks do you have in mind?")
# ('Liam Carter', 'I think we could work on analyzing our recent campaign metrics together. It would be great to get your insights! What do you think?')
# ('Clara Thompson', "I think that's a fantastic idea, Liam! I have some thoughts on the metrics we should focus on. Which specific areas do you want to analyze first?")
# ('Liam Carter', 'I think we should start by looking at the engagement rates first. They can give us a good idea of how our audience is responding to the content. After that, we could dive into conversion metrics. What do you think?')
# ('Clara Thompson', "I completely agree, Liam! Let's start with the engagement rates. I can pull up the data we have and analyze it together. After that, we can move on to conversion metrics.")
# ('Liam Carter', 'Great! Once you have the data, we can look for trends and see what content performed best. I’m curious to find out if there are any patterns in audience engagement.')
# ('Clara Thompson', 'Absolutely, Liam! I’ll analyze the data for trends and see which content performed best. It will be interesting to uncover any patterns in audience engagement.')
# ('Liam Carter', "I'm looking forward to seeing what you find! Maybe we can also think about how to improve our content based on the insights we gather. Do you have any initial thoughts on that?")
# ('Clara Thompson', 'I think we could enhance our content by focusing on more engaging visuals and clearer messaging. We might also consider varying the formats, like incorporating videos or infographics to capture attention better.')
# ('Liam Carter', "I love those ideas! Incorporating videos and infographics could really help us stand out. Let's brainstorm some specific concepts we can use for our next campaign.")
#             author                                            content
# 0             USER      Get some work done together, help each other.
# 1   Clara Thompson  That sounds like a great idea! I'm always up f...
# 2      Liam Carter  I think we could work on analyzing our recent ...
# 3   Clara Thompson  I think that's a fantastic idea, Liam! I have ...
# 4      Liam Carter  I think we should start by looking at the enga...
# 5   Clara Thompson  I completely agree, Liam! Let's start with the...
# 6      Liam Carter  Great! Once you have the data, we can look for...
# 7   Clara Thompson  Absolutely, Liam! I’ll analyze the data for tr...
# 8      Liam Carter  I'm looking forward to seeing what you find! M...
# 9   Clara Thompson  I think we could enhance our content by focusi...
# 10     Liam Carter  I love those ideas! Incorporating videos and i...

# %%
df.to_csv("../data/extractions/synthetic_data_generation.out.csv", index=False)

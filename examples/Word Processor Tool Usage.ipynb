# %% [markdown]
# # Wordprocessor usage example

# %%
import json
import sys
import csv
sys.path.insert(0, '..') # ensures that the package is imported from the parent directory, not the Python installation


import tinytroupe
from tinytroupe.factory import TinyPersonFactory
from tinytroupe.agent import TinyPerson, TinyToolUse
from tinytroupe.environment import TinyWorld
from tinytroupe import control
from tinytroupe.extraction import ResultsExtractor, ResultsReducer
from tinytroupe.enrichment import TinyEnricher
from tinytroupe.extraction import ArtifactExporter
from tinytroupe.tools import TinyWordProcessor
from tinytroupe.steering import TinyStory
import tinytroupe.utils as utils
from tinytroupe.examples import create_lisa_the_data_scientist, create_oscar_the_architect, create_marcos_the_physician
# Out:
# !!!!
# DISCLAIMER: TinyTroupe relies on Artificial Intelligence (AI) models to generate content.
# The AI models are not perfect and may produce inappropriate or inaccurate results.
# For any serious or consequential use, please review the generated content before using it.
# !!!!
#
# Looking for default config on: C:\Users\pdasilva\repos\TinyTroupe and personal repos\TinyTroupe\examples\..\tinytroupe\utils\..\config.ini
# Found custom config on: C:\Users\pdasilva\repos\TinyTroupe and personal repos\TinyTroupe\examples\config.ini
# TinyTroupe version: 0.8.0
# Current date and time (local): 2026-06-08 20:50:59
# Current date and time (UTC):   2026-06-09 03:50:59
#
# =================================
# Current TinyTroupe configuration
# =================================
# [OpenAI]
# api_type = openai
# azure_api_version = 2024-08-01-preview
# model = gpt-5-mini
# reasoning_model = o3-mini
# vision_detail = auto
# embedding_model = text-embedding-3-small
# azure_embedding_model_api_version = 2023-05-15
# max_completion_tokens = 128000
# timeout = 480
# max_attempts = 5
# waiting_time = 0
# exponential_backoff_factor = 5
# max_concurrent_model_calls = 4
# reasoning_effort = high
# cache_api_calls = False
# cache_file_name = openai_api_cache.json
# max_content_display_length = 1024
#
# [Simulation]
# parallel_agent_generation = True
# parallel_agent_actions = True
# rai_harmful_content_prevention = True
# rai_copyright_infringement_prevention = True
#
# [Cognition]
# enable_memory_consolidation = True
# enable_continuous_contextual_semantic_memory_retrieval = True
# min_episode_length = 10
# max_episode_length = 15
# episodic_memory_fixed_prefix_length = 10
# episodic_memory_lookback_length = 20
#
# [ActionGenerator]
# max_attempts = 2
# enable_quality_checks = False
# enable_regeneration = True
# enable_direct_correction = False
# enable_quality_check_for_persona_adherence = True
# enable_quality_check_for_selfconsistency = False
# enable_quality_check_for_fluency = False
# enable_quality_check_for_suitability = False
# enable_quality_check_for_similarity = False
# continue_on_failure = True
# quality_threshold = 5
#
# [Logging]
# loglevel = ERROR
# loglevel_console = ERROR
# loglevel_file = DEBUG
# log_include_thread_id = True

# %%
data_export_folder = "../data/extractions/wordprocessor"

# %%
exporter = ArtifactExporter(base_output_folder=data_export_folder)
enricher = TinyEnricher()

# %%
lisa = create_lisa_the_data_scientist()

# %%
lisa.add_mental_faculties([TinyToolUse(tools=[TinyWordProcessor(owner=lisa, exporter=exporter, enricher=enricher)])])
# Out:
# TinyPerson(name='Lisa Carter')

# %%
lisa.listen_and_act("You have just been fired and need to find a new job. You decide to think about what you want in life and then write a resume. Make it very detailed.")
# Out:
# USER --> Lisa Carter: [CONVERSATION]
#           > You have just been fired and need to find a new job. You decide to think about what you
#           > want in life and then write a resume. Make it very detailed.
# Lisa Carter acts: [THINK]
#                  > I was just told I'm fired. Immediate priorities: 1) take a calm inventory of my
#                  > skills, experience, and preferences; 2) produce a very detailed resume that
#                  > highlights strengths and accomplishments for data-science / search / NLP roles;
#                  > 3) clarify job targets (search/NLP, product-focused ML, or applied research) so
#                  > the resume can be tailored quickly. I should emphasize measurable impact where
#                  > possible, my thesis and internship background, production ML experience at
#                  > Microsoft, and technical stack (Python, pandas, scikit-learn, TensorFlow, Azure
#                  > ML, SQL, Power BI). Keep tone professional, clear, and confident. Keep in mind
#                  > privacy—avoid inventing precise personal contact details or false dates. I'll
#                  > draft a full, structured resume document in Markdown, with sections: Summary,
#                  > Experience, Selected Projects, Education, Technical Skills, Tools & Platforms,
#                  > Mentoring & Collaboration, and Additional Info.
# Lisa Carter acts: [TINYWORDPROCESSOR::WRITE_DOCUMENT]
#                  > {"title": "Resume - Lisa Carter", "author": "Lisa Carter", "content": "# Lisa
#                  > Carter\n\n**Data Scientist — Search & NLP**\n\nLocation: Seattle, WA (open to
#                  > remote / relocation)\n\n---\n\n## Professional Summary\n\nData scientist with a
#                  > Master’s in Data Science from the University of Toronto and hands-on experience
#                  > building and shipping production machine learning solutions for search and
#                  > conversational AI. Strong background in query understanding, ranking, and
#                  > evaluation; skilled at turning noisy user behavior and feedback signals into
#                  > reliable features and models. Comfortable across the ML lifecycle: data
#                  > ingestion, feature engineering, model development, A/B testing, and production
#                  > monitoring. Collaborative, detail-oriented, and committed to ethically
#                  > responsible ML.\n\n---\n\n## Professional Experience\n\n### Microsoft — Data
#                  > Scientist, M365 Search Team\n- Role summary: Owned analysis and modeling efforts
#                  > to improve search relevance and user satisfaction across Microsoft 365 search
#                  > surfaces. Worked closely (...)
# [DEBUG] Ensuring pandoc path...
# [DEBUG] Verifying format...
# [DEBUG] Identifying input type...
# [DEBUG] Running pandoc...
# Lisa Carter acts: [TALK]
#                  > I drafted a detailed resume document (saved as 'Resume - Lisa Carter'). Next
#                  > steps I recommend: 1) review the resume and tell me where you'd like it tailored
#                  > (e.g., emphasize search ranking vs. conversational AI vs. applied research); 2)
#                  > provide any dates, contact details, or metrics you want included; 3) I can then
#                  > produce a version formatted for LinkedIn, a one-page CV, or tailored job-specific
#                  > versions. Which would you like first?
# Lisa Carter acts: [DONE]
#                  > Completed drafting detailed resume and asked for tailoring preferences.

# %%
lisa.listen_and_act("What did I just told you?")
# Out:
# USER --> Lisa Carter: [CONVERSATION]
#           > What did I just told you?
# Lisa Carter acts: [THINK]
#                  > User asked: "What did I just told you?" I recall the recent event: they told me
#                  > they were just fired and needed to find a new job. I already drafted a detailed
#                  > resume titled 'Resume - Lisa Carter' and recommended next steps: review the
#                  > resume, decide which role to emphasize (search ranking vs. conversational AI vs.
#                  > applied research), provide any dates/contact details/metrics to include, and
#                  > request which formatted output they want first (LinkedIn, one-page CV, or job-
#                  > specific versions). Plan for next action: confirm those points succinctly and ask
#                  > which tailoring option they'd like me to produce first.
# Lisa Carter acts: [TALK]
#                  > You told me you were just fired and needed to find a new job. I drafted a very
#                  > detailed resume (saved as "Resume - Lisa Carter") and recommended next steps: 1)
#                  > review the resume and tell me which role to emphasize — search ranking,
#                  > conversational AI, or applied research; 2) provide any dates, contact details, or
#                  > specific metrics you want included; and 3) pick the first output you want me to
#                  > produce (LinkedIn-optimized profile, a one-page CV, or a job-tailored resume).
#                  > Which would you like me to do first?
# Lisa Carter acts: [DONE]
#                  > Waiting for instructions on how to tailor the resume.
